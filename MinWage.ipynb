# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plot
import numpy as np
import seaborn as sns

df = pd.read_csv('Minimum Wage Data.csv', encoding='latin')
df.to_csv('minwage.csv', encoding='utf-8')

# %%
df = pd.read_csv('minwage.csv')
df = df.set_index('Year')
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df
# Out:
#               State  State.Minimum.Wage  State.Minimum.Wage.2020.Dollars  \
# Year
# 1968        Alabama             0.00000                             0.00
# 1968         Alaska             2.10000                            15.61
# 1968        Arizona             0.46800                             3.48
# 1968       Arkansas             0.15625                             1.16
# 1968     California             1.65000                            12.26
# ...             ...                 ...                              ...
# 2020       Virginia             7.25000                             7.25
# 2020     Washington            13.50000                            13.50
# 2020  West Virginia             8.75000                             8.75
# 2020      Wisconsin             7.25000                             7.25
# 2020        Wyoming             5.15000                             5.15
#
#       Federal.Minimum.Wage  Federal.Minimum.Wage.2020.Dollars  \
# Year
# ...

# %%
grouped_by_state=df.groupby('State')
#grouped_by_state[['State.Minimum.Wage.2020.Dollars']].apply(print)

# %%
act_min_wage = pd.DataFrame()

for name, group in df.groupby('State'):
    if act_min_wage.empty:
        act_min_wage = group[['State.Minimum.Wage.2020.Dollars']].rename(columns={'State.Minimum.Wage.2020.Dollars':name})
    else:
        act_min_wage = act_min_wage.join(group[['State.Minimum.Wage.2020.Dollars']].rename(columns={'State.Minimum.Wage.2020.Dollars':name}))
act_min_wage
# Out:
#       Alabama  Alaska  Arizona  Arkansas  California  Colorado  Connecticut  \
# Year
# 1968      0.0   15.61     3.48      1.16       12.26      7.43        10.41
# 1969      0.0   14.80     3.30      1.10       11.63      7.05         9.87
# 1970      0.0   14.00     3.12      7.33       11.00      6.67        10.67
# 1971      0.0   13.41     2.99      7.03       10.54      6.39        10.22
# 1972      0.0   12.99     2.90      7.43       10.21      6.19        11.45
# 1973      0.0   12.23     2.73      6.99        9.61      5.83        10.78
# 1974      0.0   11.02     2.46      6.30        8.66      5.25         9.71
# 1975      0.0   10.10     2.25      5.77        7.93      4.81         8.89
# 1976      0.0   12.73     0.00      8.64        9.09      4.55        10.05
# 1977      0.0   11.95     0.00      8.11        8.54      4.27         9.43
# 1978      0.0   11.11     0.00      7.54        7.93      3.97         8.77
# ...

# %%
act_min_wage.describe()
# Out:
#        Alabama     Alaska    Arizona   Arkansas  California   Colorado  \
# count     53.0  53.000000  53.000000  53.000000   53.000000  53.000000
# mean       0.0   9.917736   2.917358   7.139245    9.101132   6.881698
# std        0.0   1.852213   4.102247   1.459132    1.418712   1.921086
# min        0.0   7.620000   0.000000   1.100000    6.630000   3.970000
# 25%        0.0   8.590000   0.000000   6.780000    8.000000   5.250000
# 50%        0.0   9.260000   0.000000   7.210000    9.010000   6.670000
# 75%        0.0  10.510000   8.290000   7.740000    9.710000   8.430000
# max        0.0  15.610000  12.140000  10.000000   13.000000  12.140000
#
#        Connecticut   Delaware  District of Columbia    Florida  ...  \
# count    53.000000  53.000000             53.000000  53.000000  ...
# mean      9.212830   7.818679              8.919245   2.415283  ...
# std       1.106907   1.307834              1.932959   3.882305  ...
# ...

# %%
act_min_wage.corr()
corr_min_wage = act_min_wage.corr().fillna(0)
corr_min_wage
# Out:
#                       Alabama    Alaska   Arizona  Arkansas  California  \
# Alabama                   0.0  0.000000  0.000000  0.000000    0.000000
# Alaska                    0.0  1.000000  0.037101 -0.332127    0.622245
# Arizona                   0.0  0.037101  1.000000  0.271834    0.639006
# Arkansas                  0.0 -0.332127  0.271834  1.000000    0.030265
# California                0.0  0.622245  0.639006  0.030265    1.000000
# Colorado                  0.0 -0.078678  0.820730  0.333597    0.649967
# Connecticut               0.0  0.646909  0.555455  0.183662    0.881831
# Delaware                  0.0  0.260265  0.477781  0.107639    0.518481
# District of Columbia      0.0  0.271810  0.723523  0.433775    0.727373
# Florida                   0.0 -0.193062  0.907295  0.340509    0.443946
# Georgia                   0.0 -0.567726  0.084376  0.442474   -0.318568
# Guam                      0.0  0.787515  0.044794  0.037006    0.411729
# ...

# %%
labels = [c[:2] for c in corr_min_wage.columns]  # get abbv state names.

fig = plot.figure(figsize=(20,15))  # figure so we can add axis
ax = fig.add_subplot(111)  # define axis, so we can modify
ax.matshow(corr_min_wage, cmap=plot.cm.RdYlGn)  # display the matrix
ax.set_xticks(np.arange(len(labels)))  # show them all!
ax.set_yticks(np.arange(len(labels)))  # show them all!
ax.set_xticklabels(labels)  # set to be the abbv (vs useless #)
ax.set_yticklabels(labels)  # set to be the abbv (vs useless #)

plot.show()

# %%
sns.heatmap(act_min_wage)
plot.show()

# %%
sns.heatmap(corr_min_wage)
plot.show()

# %%
sns.kdeplot(x=df['State.Minimum.Wage.2020.Dollars'], y=df['Federal.Minimum.Wage.2020.Dollars'], cmap='Reds', fill=True)
plot.show()

# %%
plot.hist2d(x=df['State.Minimum.Wage.2020.Dollars'], y=df['Federal.Minimum.Wage.2020.Dollars'])
plot.show()

# %%
sns.jointplot(x=df['State.Minimum.Wage.2020.Dollars'], y=df['Federal.Minimum.Wage.2020.Dollars'], kind='kde', fill=True)
sns.jointplot(x=df['State.Minimum.Wage.2020.Dollars'], y=df['Federal.Minimum.Wage.2020.Dollars'], kind='hex')
plot.show()

# %%
sns.pairplot(df[['State.Minimum.Wage.2020.Dollars', 'Federal.Minimum.Wage.2020.Dollars','Effective.Minimum.Wage.2020.Dollars', 'CPI.Average']], kind='hist')
plot.show()

# %%
f_df = df[['State.Minimum.Wage.2020.Dollars', 'Federal.Minimum.Wage.2020.Dollars','Effective.Minimum.Wage.2020.Dollars', 'CPI.Average']]
g=sns.PairGrid(f_df)
g.map_upper(sns.scatterplot)
g.map_lower(sns.kdeplot)
g.map_diag(sns.kdeplot)
